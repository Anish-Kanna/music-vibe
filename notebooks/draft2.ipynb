# %%
SAMPLE_RATE = 22050
CLIP_DURATION = 10.0
N_FFT = 2048
HOP_LENGTH = 512
N_MELS = 128

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import librosa
from tqdm import tqdm


data_dir = Path("/Users/anish/Desktop/music-vibe/data/genres_original")
files = list(data_dir.rglob("*.wav"))
print("Total WAV files found:", len(files))
print("Example:", files[0])
# Out:
# Total WAV files found: 1000
# Example: \Users\anish\Desktop\music-vibe\data\genres_original\blues\blues.00000.wav
