# %%
import librosa, librosa.display, matplotlib.pyplot as plt
import numpy as np
from glob import glob
audio_file = glob("/Users/anish/Desktop/music-vibe/data/genres_original/*/*.wav")
y, sr = librosa.load(audio_file[0], sr=22050, mono=True)
plt.figure(figsize=(12, 3))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform")
plt.show()

S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
logS = librosa.power_to_db(S)
plt.figure(figsize=(8, 4))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='mel')
plt.title("Mel-Spectrogram")
plt.colorbar()
plt.show()

# %%
D = librosa.stft(y)
DB = librosa.amplitude_to_db(np.abs(D), ref = np.max)
DB.shape
# Out:
# (1025, 1293)

# %%
fig, ax = plt.subplots(figsize=(12, 4))
img = librosa.display.specshow(DB, sr=sr, x_axis='time', y_axis='log', ax=ax)
ax.set_title('Log-frequency power spectrogram') 
plt.colorbar(img, ax=ax, format="%+2.0f dB")
plt.show()

# %%
import soundfile as sf
info = sf.info(audio_file[0])
print(info.samplerate, info.frames)
print("Duration:", info.frames / info.samplerate)
# Out:
# 22050 661794
# Duration: 30.013333333333332

# %%
import IPython.display as ipd
ipd.Audio(audio_file[999])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
